# %%
import pandas as pd 

file_path=(r"C:\Users\abdul\OneDrive\Desktop\PROJECTS\HR DATA SET\attendance.xlsx")
df = pd.read_excel(file_path)

# %% [raw]
# import pandas as pd
# file_path = (r"C:\Users\abdul\OneDrive\Desktop\PROJECTS\HR DATA SET\departments.xlsx")
# df = pd.read_excel(file_path)

# %%
import pandas as pd
file_path = (r"C:\Users\abdul\OneDrive\Desktop\PROJECTS\HR DATA SET\employees.xlsx")
df = pd.read_excel(file_path)

# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:root@localhost/projects")
files={
    "employees": r"C:\Users\abdul\OneDrive\Desktop\PROJECTS\HR DATA SET\employees.xlsx",
    "departments": r"C:\Users\abdul\OneDrive\Desktop\PROJECTS\HR DATA SET\departments.xlsx",
    "attendance": r"C:\Users\abdul\OneDrive\Desktop\PROJECTS\HR DATA SET\attendance.xlsx"
}
for table, path in files.items():
    df = pd.read_excel(path)
    df.columns = df.columns.str.replace(r'[^0-9a-zA-Z]+','_',regex=True)
    df.to_sql(table,con=engine,if_exists="replace",index=False)
    print(f"Loaded {table} into database with cleaned column name")
# Out:
# Loaded employees into database with cleaned column name
# Loaded departments into database with cleaned column name
# Loaded attendance into database with cleaned column name

# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:root@localhost/test
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# use projects
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# select * from attendance
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 30 rows affected.
# [(110, datetime.datetime(2024, 12, 4, 0, 0), 'Remote'),
#  (107, datetime.datetime(2024, 12, 4, 0, 0), 'Present'),
#  (104, datetime.datetime(2024, 12, 10, 0, 0), 'Absent'),
#  (105, datetime.datetime(2024, 12, 10, 0, 0), 'Absent'),
#  (103, datetime.datetime(2024, 12, 8, 0, 0), 'Present'),
#  (102, datetime.datetime(2024, 12, 5, 0, 0), 'Absent'),
#  (104, datetime.datetime(2024, 12, 8, 0, 0), 'Present'),
#  (102, datetime.datetime(2024, 12, 3, 0, 0), 'Absent'),
#  (110, datetime.datetime(2024, 12, 5, 0, 0), 'Present'),
#  (106, datetime.datetime(2024, 12, 7, 0, 0), 'Remote'),
#  (102, datetime.datetime(2024, 12, 8, 0, 0), 'Absent'),
#  (108, datetime.datetime(2024, 12, 6, 0, 0), 'Present'),
#  (107, datetime.datetime(2024, 12, 9, 0, 0), 'Remote'),
#  (101, datetime.datetime(2024, 12, 2, 0, 0), 'Absent'),
#  (103, datetime.datetime(2024, 12, 7, 0, 0), 'Absent'),
# ...

# %%
# %%sql
# select * from departments
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 4 rows affected.
# [(201, 'HR', 'Sophia'),
#  (202, 'Finance', 'Liam'),
#  (203, 'IT', 'Olivia'),
#  (204, 'Sales', 'Mason')]

# %%
# %%sql
# select * from employees
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 10 rows affected.
# [(101, 'Alice', 'HR', 45000, datetime.datetime(2020, 1, 15, 0, 0), 201),
#  (102, 'Bob', 'Finance', 55000, datetime.datetime(2019, 3, 10, 0, 0), 202),
#  (103, 'Charlie', 'IT', 60000, datetime.datetime(2021, 6, 20, 0, 0), 203),
#  (104, 'David', 'IT', 75000, datetime.datetime(2018, 7, 1, 0, 0), 203),
#  (105, 'Eva', 'Sales', 50000, datetime.datetime(2022, 2, 12, 0, 0), 204),
#  (106, 'Frank', 'Finance', 65000, datetime.datetime(2017, 11, 23, 0, 0), 202),
#  (107, 'Grace', 'Sales', 48000, datetime.datetime(2021, 12, 1, 0, 0), 204),
#  (108, 'Hannah', 'HR', 47000, datetime.datetime(2019, 9, 15, 0, 0), 201),
#  (109, 'Ian', 'IT', 80000, datetime.datetime(2023, 4, 1, 0, 0), 203),
#  (110, 'Jack', 'Sales', 52000, datetime.datetime(2022, 8, 19, 0, 0), 204)]

# %%
# %%sql
# /*Which department has the highest number of employees?*/
# select
# department,
# count(name) as total_emp
# from employees
# group by department
# order by total_emp desc
# limit 1
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [('Sales', 3)]

# %%
# %%sql
# /*Aggregate by Department
# 👉 Find the average number of working days (Present) for employees in each department in January 2024.*/
# with present_days as(
#     select
#         e.department,
#         a.employeeid,
#         count(*) as total_present_days
#     from attendance a
#     join employees e
#               on a.employeeid = e.employeeid
#     where status = "present"
#    and year(a.date)=2024
#    group by e.department,a.employeeid
# )
# select
#  department,
#  avg(total_present_days) as avg_present_days
#  from present_days
#  group by department
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 4 rows affected.
# [('IT', Decimal('1.6667')),
#  ('Sales', Decimal('1.0000')),
#  ('Finance', Decimal('1.0000')),
#  ('HR', Decimal('1.0000'))]

# %%
# %%sql
# select
#       e.department,
#         a.employeeid,
#         count(*) as total_present_days
#     from attendance a
#     join employees e
#               on a.employeeid = e.employeeid
#     where status = "present"
# and year(a.date)=2024
# group by e.department,a.employeeid
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 8 rows affected.
# [('IT', 103, 2),
#  ('IT', 104, 1),
#  ('Sales', 105, 1),
#  ('Finance', 106, 1),
#  ('Sales', 107, 1),
#  ('HR', 108, 1),
#  ('IT', 109, 2),
#  ('Sales', 110, 1)]

# %%
# %%sql
# /*Aggregate by Department
# 👉 Find the average number of present days for employees in each department */
# with present_avg as(
# select
# count(status)as total,
# Status
# from attendance
# group by status
# )
# select
# avg(total) as avg_present,status
# from present_avg
# group by status
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(Decimal('5.0000'), 'Remote'),
#  (Decimal('10.0000'), 'Present'),
#  (Decimal('15.0000'), 'Absent')]

# %%
# %%sql
# select
# count(status)as total,
# Status
# from attendance
# group by status
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(5, 'Remote'), (10, 'Present'), (15, 'Absent')]

# %%
# %%sql
# /*Find the total number of employees in each department.*/
# select
#   count(name) as total_employee,
#   department
# from employees
# group by department
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 4 rows affected.
# [(2, 'HR'), (2, 'Finance'), (3, 'IT'), (3, 'Sales')]

# %%
# %%sql
# /*Manager-Employee Relation
# 👉 Get the list of departments along with their manager name.*/
# select
# count(e.name) as total_employee,
# d.departmentname,
# d.head as manager_name
# from employees e
# join departments d
# on d.departmentid = e.managerid
# group by d.head,d.departmentname
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 4 rows affected.
# [(2, 'HR', 'Sophia'),
#  (2, 'Finance', 'Liam'),
#  (3, 'IT', 'Olivia'),
#  (3, 'Sales', 'Mason')]

# %%
# %%sql
# /*Attendance Analysis
# 👉 Find the total number of absent days for each employee in 2024*/
# select
# count(status) as total_days,
# status
# from attendance
# where status = "absent"
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(15, 'Absent')]

# %%
# %%sql
# /*Filter + Join
# 👉 Get the names of employees who belong to the “HR” department.*/
# select
#     name,
#     department
#     from employees
# where department = "HR"
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [('Alice', 'HR'), ('Hannah', 'HR')]

# %%
# %%sql
# /*Employee Details
# 👉 List all employees along with their department name.*/
# select
#
#     name,
#
#     department
#
# from employees
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 10 rows affected.
# [('Alice', 'HR'),
#  ('Bob', 'Finance'),
#  ('Charlie', 'IT'),
#  ('David', 'IT'),
#  ('Eva', 'Sales'),
#  ('Frank', 'Finance'),
#  ('Grace', 'Sales'),
#  ('Hannah', 'HR'),
#  ('Ian', 'IT'),
#  ('Jack', 'Sales')]

# %%
# %%sql
# /*Basic Count
# 👉 Find the total number of departments in the company.*/
# select
#     count(department) as tatal_dept,
#     department
# from employees
# group by department
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 4 rows affected.
# [(2, 'HR'), (2, 'Finance'), (3, 'IT'), (3, 'Sales')]

# %%
# %%sql
# /*Total number of working days (Status = "Present") for each employee */
# select
#     year(a.Date) as year,
#     month(a.Date) as month,
#     a.employeeid,
#     e.name,
#     e.department,
#     a.Status
# from employees e
#     join attendance a
# on a.employeeid = e.employeeid
#     join departments d
# on d.departmentid = e.managerid
# where status = "present"
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 10 rows affected.
# [(2024, 12, 108, 'Hannah', 'HR', 'Present'),
#  (2024, 12, 106, 'Frank', 'Finance', 'Present'),
#  (2024, 12, 109, 'Ian', 'IT', 'Present'),
#  (2024, 12, 109, 'Ian', 'IT', 'Present'),
#  (2024, 12, 104, 'David', 'IT', 'Present'),
#  (2024, 12, 103, 'Charlie', 'IT', 'Present'),
#  (2024, 12, 103, 'Charlie', 'IT', 'Present'),
#  (2024, 12, 110, 'Jack', 'Sales', 'Present'),
#  (2024, 12, 107, 'Grace', 'Sales', 'Present'),
#  (2024, 12, 105, 'Eva', 'Sales', 'Present')]

# %%
# %%sql
# /*Total number of working days (Status = "Present") for each employee in January 2024*/
# select
#     e.employeeid,
#     e.name,
#     e.department,
#     count(*) as total_prestnt_days
# from employees e
#     join attendance a
# on a.employeeid = e.employeeid
#     join departments d
# on d.departmentid = e.managerid
# where a.status = "present"
#      and year(a.date)=2024
#      and month(a.date)=1
# group by e.employeeid,e.name,e.department;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %% [raw]
# import pandas as pd
# from sqlalchemy import create_engine
#
# engine = create_engine("mysql+pymysql://root:root@localhost/projects")
# folder = r"C:\Users\abdul\OneDrive\Desktop\PROJECTS\HR DATA SET\hr_data_set"
#
# queries ={
#
#
#     "open attendance table":""" select * from attendance""",
#
#     "open departments table":"""select * from departments""",
#
#     "open employees table":"""select * from employees""",
#
# "Employee Details List all employees along with their department name":"""
#      select
#         name,
#         department
#      from employees
# """,
#
# "Total number of working days Status Present for each employee in January":"""
#      select
#          e.employeeid,
#          e.name,
#          e.department,
#          count(*) as total_prestnt_days
#     from employees e
#     join attendance a
#           on a.employeeid = e.employeeid
#     join departments d
#           on d.departmentid = e.managerid
#     where a.status = "present"
#           and year(a.date)=2024
#           and month(a.date)=1
# group by e.employeeid,e.name,e.department
# """,
#
#
# "Total number of working days Status Present for each employee":"""
#      select
#         year(a.Date) as year,
#         month(a.Date) as month,
#         a.employeeid,
#         e.name,
#         e.department,
#         a.Status
#      from employees e
#      join attendance a
#         on a.employeeid = e.employeeid
#     join departments d
#         on d.departmentid = e.managerid
#     where status = 'present'
# """,
#
# "Basic Count Find the total number of departments in the company":"""
#      select
#          count(department) as total_dept,
#          department
#      from employees
#      group by department
# """,
#
# " Get the names of employees who belong to the HR department":"""
#       select
#          name,
#          department
#       from employees
#       where department = 'HR'
# """,
#
# " Find the total number of absent days for each employee":"""
#      select
#         count(status) as total_days,
#         status
#     from attendance
#     where status = 'absent'
# """,
#
#
# "Manager-Employee Relation Get the list of departments along with their manager name":"""
#      select
#         count(e.name) as total_employee,
#         d.departmentname,
#         d.head as manager_name
#      from employees e
#      join departments d
#         on d.departmentid = e.managerid
#      group by d.head,d.departmentname
# """,
#
#
# "Find the total number of employees in each department":"""
#     select
#        count(name) as total_employee,
#        department
#     from employees
#     group by department
# """,
#
#
# "Find the  number of working days Present for employees in each department":"""
#      select
#         e.department,
#         a.employeeid,
#         count(*) as total_present_days
#      from attendance a
#      join employees e
#         on a.employeeid = e.employeeid
#      where status = "present"
#         and year(a.date)=2024
#      group by e.department,a.employeeid
# """,
#
#
# "Aggregate by Department Find the average number of present days for employees in each department":"""
#   with present_avg as(
#       select
#           count(status)as total,
#           Status
#          from attendance
#       group by status
#  )
#   select
#      avg(total) as avg_present,status
#   from present_avg
#   group by status
# """,
#
#
# "Aggregate by Department Find the average number of working days Present for employees in each department":"""
# with present_days as(
#     select
#         e.department,
#         a.employeeid,
#         count(*) as total_present_days
#     from attendance a
#     join employees e
#               on a.employeeid = e.employeeid
#     where status = "present"
#    and year(a.date)=2024
#    group by e.department,a.employeeid
# )
# select
#  department,
#  avg(total_present_days) as avg_present_days
#  from present_days
#  group by department
# """
#
# }
# for name, query in queries.items():
#     try:
#         df = pd.read_sql(query, engine)
#         file_path = f"{folder}\\{name}.csv"
#         df.to_csv(file_path, index=False)
#         print(f"✅ Saved {file_path}")
#     except Exception as e:
#         print(f"❌ Error in query '{name}': {e}")

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:root@localhost/projects")
folder = r"C:\Users\abdul\OneDrive\Desktop\PROJECTS\HR DATA SET\hr_data_set"

queries = {
    "open attendance table": """select * from attendance""",
    "open departments table": """select * from departments""",
    "open employees table": """select * from employees""",

    "Employee Details List all employees along with their department name": """
        select 
            name,
            department
        from employees
    """,

    "Total number of working days Status Present for each employee in January": """
        select
            e.employeeid,
            e.name,
            e.department,
            count(*) as total_present_days
        from employees e
        join attendance a on a.employeeid = e.employeeid 
        join departments d on d.departmentid = e.managerid 
        where a.status = 'present'
          and year(a.date) = 2024
          and month(a.date) = 1
        group by e.employeeid, e.name, e.department
    """,

    "Total number of working days Status Present for each employee": """
        select
            year(a.Date) as year,
            month(a.Date) as month,
            a.employeeid,
            e.name,
            e.department,
            a.Status
        from employees e
        join attendance a on a.employeeid = e.employeeid 
        join departments d on d.departmentid = e.managerid 
        where status = 'present'
    """,

    "Basic Count Find the total number of departments in the company": """
        select 
            count(department) as total_dept,
            department
        from employees 
        group by department
    """,

    "Get the names of employees who belong to the HR department": """
        select 
            name,
            department
        from employees
        where department = 'HR'
    """,

    "Find the total number of absent days for each employee": """
        select 
            employeeid,
            count(*) as total_absent_days
        from attendance
        where status = 'absent'
        group by employeeid
    """,

    "Manager-Employee Relation Get the list of departments along with their manager name": """
        select 
            count(e.name) as total_employee,
            d.departmentname,
            d.head as manager_name
        from employees e
        join departments d on d.departmentid = e.managerid
        group by d.head, d.departmentname
    """,

    "Find the total number of employees in each department": """
        select  
            count(name) as total_employee,
            department
        from employees 
        group by department
    """,

    "Find the number of working days Present for employees in each department": """
        select 
            e.department,
            a.employeeid,
            count(*) as total_present_days
        from attendance a
        join employees e on a.employeeid = e.employeeid
        where status = 'present'
          and year(a.date) = 2024
        group by e.department, a.employeeid
    """,

    "Aggregate by Department Find the average number of present days for employees in each department": """
        with present_days as (
            select 
                e.department,
                a.employeeid,
                count(*) as total_present_days
            from attendance a
            join employees e on a.employeeid = e.employeeid
            where status = 'present'
              and year(a.date) = 2024
            group by e.department, a.employeeid
        )
        select
            department,
            avg(total_present_days) as avg_present_days
        from present_days
        group by department
    """
}

for name, query in queries.items():
    try:
        df = pd.read_sql(query, engine)
        file_path = f"{folder}\\{name}.csv"
        df.to_csv(file_path, index=False)
        print(f"✅ Saved {file_path}")
    except Exception as e:
        print(f"❌ Error in query '{name}': {e}")
# Out:
# ✅ Saved C:\Users\abdul\OneDrive\Desktop\PROJECTS\HR DATA SET\hr_data_set\open attendance table.csv
# ✅ Saved C:\Users\abdul\OneDrive\Desktop\PROJECTS\HR DATA SET\hr_data_set\open departments table.csv
# ✅ Saved C:\Users\abdul\OneDrive\Desktop\PROJECTS\HR DATA SET\hr_data_set\open employees table.csv
# ✅ Saved C:\Users\abdul\OneDrive\Desktop\PROJECTS\HR DATA SET\hr_data_set\Employee Details List all employees along with their department name.csv
# ✅ Saved C:\Users\abdul\OneDrive\Desktop\PROJECTS\HR DATA SET\hr_data_set\Total number of working days Status Present for each employee in January.csv
# ✅ Saved C:\Users\abdul\OneDrive\Desktop\PROJECTS\HR DATA SET\hr_data_set\Total number of working days Status Present for each employee.csv
# ✅ Saved C:\Users\abdul\OneDrive\Desktop\PROJECTS\HR DATA SET\hr_data_set\Basic Count Find the total number of departments in the company.csv
# ...

# %%
import os

# Check if folder exists, if not create it
if not os.path.exists(folder):
    os.makedirs(folder)
    print(f"📂 Created folder: {folder}")
else:
    print(f"📂 Folder already exists: {folder}")
# Out:
# 📂 Folder already exists: C:\Users\abdul\OneDrive\Desktop\PROJECTS\HR DATA SET\hr_data_set

# %%
import pandas as pd
import os
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:root@localhost/projects")

folder = r"C:\Users\abdul\OneDrive\Desktop\PROJECTS\HR DATA SET\hr_data_set"

# ✅ Ensure folder exists
if not os.path.exists(folder):
    os.makedirs(folder)
    print(f"📂 Created folder: {folder}")
else:
    print(f"📂 Folder already exists: {folder}")
# Out:
# 📂 Folder already exists: C:\Users\abdul\OneDrive\Desktop\PROJECTS\HR DATA SET\hr_data_set
